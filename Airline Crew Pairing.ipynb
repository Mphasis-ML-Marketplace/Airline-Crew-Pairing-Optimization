# %% [markdown]
# ## Execute a Classical Optimization model using Airline Crew Pairing Algorithm from AWS Marketplace
#
#
# The solution uses a classical optimization based approach to derive pairings, i.e., combination of flight legs.
#
#
#
# This sample notebook shows you how to execute a Classical Optimization model using Airline Crew Pairing Algorithm from AWS Marketplace
#
# > **Note**: This is a reference notebook and it cannot run unless you make changes suggested in the notebook.
#
# #### Pre-requisites:
# 1. **Note**: This notebook contains elements which render correctly in Jupyter interface. Open this notebook from an Amazon SageMaker Notebook Instance or Amazon SageMaker Studio.
# 1. Ensure that IAM role used has **AmazonSageMakerFullAccess**
# 1. Some hands-on experience using [Amazon SageMaker](https://aws.amazon.com/sagemaker/).
# 1. To use this algorithm successfully, ensure that:
#     1. Either your IAM role has these three permissions and you have authority to make AWS Marketplace subscriptions in the AWS account used:
#         1. **aws-marketplace:ViewSubscriptions**
#         1. **aws-marketplace:Unsubscribe**
#         1. **aws-marketplace:Subscribe**
#     2. or your AWS account has a subscription to For Seller to update: Airline Crew Pairing Optimization.
#
# #### Contents:
# 1. [Subscribe to the algorithm](#1.-Subscribe-to-the-algorithm)
# 1. [Prepare dataset](#2.-Prepare-dataset)
# 	1. [Dataset format expected by the algorithm](#A.-Dataset-format-expected-by-the-algorithm)
# 	1. [Configure dataset](#B.-Configure-dataset)
# 	1. [Upload datasets to Amazon S3](#C.-Upload-datasets-to-Amazon-S3)
# 1. [Execute optimization model](#3.-Execute-optimization-model)
# 	1. [Set up environment](#3.1-Set-up-environment)
# 	1. [Execute model](#3.2-Execute-model)
#     1. [Visualize Output](#3.3-Inspect-the-Output-in-S3)
# 1. [Clean-up](#4.-Clean-up)
# 	1. [Unsubscribe to the listing (optional)](#Unsubscribe-to-the-listing-(optional))
#
#
# #### Usage instructions
# You can run this notebook one cell at a time (By using Shift+Enter for running a cell).

# %% [markdown]
# ### 1. Subscribe to the algorithm

# %% [markdown]
# To subscribe to the algorithm:
# 1. Open the algorithm listing page Airline Crew Pairing Optimization
# 1. On the AWS Marketplace listing,  click on **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you agree with EULA, pricing, and support terms.
# 1. Once you click on **Continue to configuration button** and then choose a **region**, you will see a **Product Arn**. This is the algorithm ARN that you need to specify while training a custom ML model. Copy the ARN corresponding to your region and specify the same in the following cell.

# %%
algo_arn ='arn:aws:sagemaker:us-east-2:786796469737:algorithm/crew-pairing-classical-sagemaker-listing-test-output-path-2'

# %% [markdown]
# ### 2. Prepare dataset

# %%
import base64
import json 
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
from urllib.parse import urlparse
import boto3
import urllib.request
import numpy as np
import tarfile
from zipfile import ZipFile
import pandas as pd
from pprint import pprint

# %% [markdown]
# #### A. Dataset format expected by the algorithm

# %% [markdown]
# The algorithm requires data in the format as described for best results:
# * Input File name should be data.zip
# * Within the zip file, inputs must be provided as a CSV file with mandatory information in columns.
# * The input data files must contain all columns specified in input data description; other columns will be ignored.
# * For detailed instructions, please refer sample notebook and algorithm input details

# %% [markdown]
# #### B. Configure dataset

# %%
training_dataset='Input/data.zip'

# %% [markdown]
# #### C. Upload datasets to Amazon S3

# %%
sagemaker_session = sage.Session()
bucket=sagemaker_session.default_bucket()

# %%
# training input location
common_prefix = "crew_pairing"
training_input_prefix = common_prefix + "/training-input-data"
TRAINING_WORKDIR = "Input"
training_input = sagemaker_session.upload_data(TRAINING_WORKDIR, key_prefix=training_input_prefix)
print("Training input uploaded to " + training_input)
# Out:
# Training input uploaded to s3://sagemaker-us-east-2-786796469737/crew_pairing/training-input-data

# %% [markdown]
# ## 3. Execute optimization model

# %% [markdown]
# Now that dataset is available in an accessible Amazon S3 bucket, we are ready to execute a optimization model.

# %% [markdown]
# ### 3.1 Set up environment

# %%
role = get_execution_role()

# %%
output_location = 's3://{}/crew_pairing/{}'.format(bucket, 'output')

# %% [markdown]
# ### 3.2 Execute model

# %% [markdown]
# For information on creating an `Estimator` object, see [documentation](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html)

# %%
training_instance_type='ml.m5.4xlarge'

# %%
#Create an estimator object for running a training job
estimator = sage.algorithm.AlgorithmEstimator(
    algorithm_arn=algo_arn,
    base_job_name="crew-pairing-training",
    role=role,
    train_instance_count=1,
    train_instance_type=training_instance_type,
    input_mode="File",
    output_path=output_location,
    sagemaker_session=sagemaker_session,
    instance_count=1,
    instance_type=training_instance_type
)
#Run the training job.
estimator.fit({"training": training_input})
# Out:
# 2022-07-04 12:21:13 Starting - Starting the training job...
# 2022-07-04 12:21:29 Starting - Preparing the instances for trainingProfilerReport-1656937273: InProgress
# ......
# 2022-07-04 12:22:43 Downloading - Downloading input data...
# 2022-07-04 12:22:59 Training - Training image download completed. Training in progress.Starting the training.
# Time taken for solver: 54.604912519454956
# 1
# {'pairings': 248, 'min flying hr time': 1.3, 'max flying hr time': 28.58, 'avg flying hr time': 7.59, 'flying hours standard deviation ': 7.51, 'number of deadhead flights': 1, 'number of flight legs not covered': 0, 'min rest time': 18.0, 'max rest time': 872.0}
# Success
#
# 2022-07-04 12:35:42 Uploading - Uploading generated training model
# 2022-07-04 12:35:42 Completed - Training job completed
# Training seconds: 779
# Billable seconds: 779

# %% [markdown]
# See this [blog-post](https://aws.amazon.com/blogs/machine-learning/easily-monitor-and-visualize-metrics-while-training-models-on-amazon-sagemaker/) for more information how to visualize metrics during the process. You can also open the training job from [Amazon SageMaker console](https://console.aws.amazon.com/sagemaker/home?#/jobs/) and monitor the metrics/logs in **Monitor** section.

# %%
#output is available on following path
estimator.output_path
# Out:
# 's3://sagemaker-us-east-2-786796469737/crew_pairing/output'

# %% [markdown]
# ## Note: Inferencing is done within training pipeline. Real time inference endpoint/batch transform job is not required.

# %% [markdown]
# ### 3.3 Inspect the Output in S3

# %%
from urllib.parse import urlparse

parsed_url = urlparse(estimator.output_path)
bucket_name = parsed_url.netloc
file_key = parsed_url.path[1:]+'/'+estimator.latest_training_job.job_name+'/output/'+"model.tar.gz"

s3_client = sagemaker_session.boto_session.client('s3')

response = s3_client.get_object(Bucket = sagemaker_session.default_bucket(), Key = file_key)

# %%
bucketFolder = estimator.output_path.rsplit('/')[3] +'/output/'+estimator.latest_training_job.job_name+'/output/'+"model.tar.gz"

# %%
import boto3
s3_conn = boto3.client("s3")
bucket_name=bucket
with open('output.tar.gz', 'wb') as f:
    s3_conn.download_fileobj(bucket_name, bucketFolder, f)
    print("Output file loaded from bucket")
# Out:
# Output file loaded from bucket

# %%
with tarfile.open('output.tar.gz') as file:
    file.extractall('./output')
with ZipFile('./output/result.zip', "r") as output_zip:
    res = json.loads(output_zip.open('results.json').read().decode('utf-8'))
    kpi = json.loads(output_zip.open('kpi.json').read().decode('utf-8'))

# %%
print('Crew Pairings:')
pprint(res)
# Out:
# Crew Pairings:
# {'pairing 1': ['LEG_08_26',
#                'LEG_08_16',
#                'LEG_08_17',
#                'LEG_09_13',
#                'LEG_09_17',
#                'LEG_10_13',
#                'LEG_13_14',
#                'LEG_14_14',
#                'LEG_17_12',
#                'LEG_17_21',
#                'LEG_17_25',
#                'LEG_18_24'],
#  'pairing 10': ['LEG_02_5', 'LEG_03_7'],
#  'pairing 100': ['LEG_01_6', 'LEG_01_8'],
#  'pairing 101': ['LEG_31_15', 'LEG_31_17'],
#  'pairing 102': ['LEG_08_31', 'LEG_08_0'],
#  'pairing 103': ['LEG_26_12', 'LEG_26_23'],
#  'pairing 104': ['LEG_10_33',
#                  'LEG_11_10',
#                  'LEG_11_11',
#                  'LEG_11_19',
#                  'LEG_11_23',
#                  'LEG_12_19'],
#  'pairing 105': ['LEG_13_28', 'LEG_13_2'],
#  'pairing 106': ['LEG_28_2', 'LEG_28_30'],
#  'pairing 107': ['LEG_26_24', 'LEG_26_25'],
#  'pairing 108': ['LEG_03_33',
#                  'LEG_04_10',
#                  'LEG_07_17',
#                  'LEG_08_13',
#                  'LEG_08_12',
#                  'LEG_08_20',
#                  'LEG_31_21',
#                  'LEG_31_5'],
#  'pairing 109': ['LEG_06_9',
#                  'LEG_06_17',
#                  'LEG_07_18',
#                  'LEG_07_15',
#                  'LEG_07_29',
#                  'LEG_07_24',
#                  'LEG_08_3',
#                  'LEG_08_2',
#                  'LEG_08_21',
#                  'LEG_08_4',
#                  'LEG_14_34',
#                  'LEG_15_11'],
#  'pairing 11': ['LEG_20_12',
#                 'LEG_20_1',
#                 'LEG_28_27',
#                 'LEG_28_6',
#                 'LEG_29_25',
#                 'LEG_29_6',
#                 'LEG_29_7',
#                 'LEG_29_13',
#                 'LEG_29_20',
#                 'LEG_30_18',
#                 'LEG_30_12',
#                 'LEG_30_10'],
#  'pairing 110': ['LEG_23_1', 'LEG_23_32'],
#  'pairing 111': ['LEG_14_22', 'LEG_14_6'],
#  'pairing 112': ['LEG_04_6', 'LEG_04_8'],
#  'pairing 113': ['LEG_07_5', 'LEG_08_7'],
#  'pairing 114': ['LEG_04_33',
#                  'LEG_05_7',
#                  'LEG_05_8',
#                  'LEG_05_16',
#                  'LEG_05_20',
#                  'LEG_06_19'],
#  'pairing 115': ['LEG_24_31',
#                  'LEG_25_11',
#                  'LEG_25_13',
#                  'LEG_25_22',
#                  'LEG_26_16',
#                  'LEG_26_11'],
#  'pairing 116': ['LEG_01_26',
#                  'LEG_01_16',
#                  'LEG_01_17',
#                  'LEG_02_13',
#                  'LEG_02_17',
#                  'LEG_03_13',
#                  'LEG_03_17',
#                  'LEG_04_13',
#                  'LEG_04_12',
#                  'LEG_04_20',
#                  'LEG_05_15',
#                  'LEG_05_11'],
#  'pairing 117': ['LEG_22_3', 'LEG_22_2'],
#  'pairing 118': ['LEG_15_1', 'LEG_15_32'],
#  'pairing 119': ['LEG_22_29', 'LEG_22_4'],
#  'pairing 12': ['LEG_23_30', 'LEG_23_0'],
#  'pairing 120': ['LEG_23_3', 'LEG_23_2'],
#  'pairing 121': ['LEG_12_29',
#                  'LEG_13_7',
#                  'LEG_14_12',
#                  'LEG_14_20',
#                  'LEG_14_24',
#                  'LEG_15_24'],
#  'pairing 122': ['LEG_08_30', 'LEG_08_28'],
#  'pairing 123': ['LEG_18_30', 'LEG_18_0'],
#  'pairing 124': ['LEG_06_28', 'LEG_06_2'],
#  'pairing 125': ['LEG_06_5', 'LEG_07_7'],
#  'pairing 126': ['LEG_20_17', 'LEG_29_8', 'LEG_30_9', 'LEG_30_16', 'LEG_30_24'],
#  'pairing 127': ['LEG_07_31', 'LEG_07_2'],
#  'pairing 128': ['LEG_08_1', 'LEG_08_34'],
#  'pairing 129': ['LEG_12_27', 'LEG_12_0'],
#  'pairing 13': ['LEG_08_23',
#                 'LEG_09_22',
#                 'LEG_09_26',
#                 'LEG_09_16',
#                 'LEG_10_11',
#                 'LEG_10_19'],
#  'pairing 130': ['LEG_11_30', 'LEG_11_28'],
#  'pairing 131': ['LEG_21_11',
#                  'LEG_21_20',
#                  'LEG_21_24',
#                  'LEG_22_24',
#                  'LEG_22_23',
#                  'LEG_22_18'],
#  'pairing 132': ['LEG_02_31', 'LEG_02_0'],
#  'pairing 133': ['LEG_04_26',
#                  'LEG_04_16',
#                  'LEG_04_17',
#                  'LEG_05_10',
#                  'LEG_05_14',
#                  'LEG_06_10',
#                  'LEG_06_14',
#                  'LEG_07_13',
#                  'LEG_13_1',
#                  'LEG_13_12'],
#  'pairing 134': ['LEG_02_23',
#                  'LEG_03_22',
#                  'LEG_03_26',
#                  'LEG_03_16',
#                  'LEG_04_11',
#                  'LEG_04_19'],
#  'pairing 135': ['LEG_08_14', 'LEG_09_35'],
#  'pairing 136': ['LEG_07_6', 'LEG_07_8'],
#  'pairing 137': ['LEG_11_1', 'LEG_11_34'],
#  'pairing 138': ['LEG_20_3', 'LEG_21_30'],
#  'pairing 139': ['LEG_30_25', 'LEG_30_6'],
#  'pairing 14': ['LEG_12_18', 'LEG_12_3'],
#  'pairing 140': ['LEG_23_10', 'LEG_24_33'],
#  'pairing 141': ['LEG_05_4', 'LEG_05_6'],
#  'pairing 142': ['LEG_15_30', 'LEG_15_0'],
#  'pairing 143': ['LEG_01_12',
#                  'LEG_01_20',
#                  'LEG_02_18',
#                  'LEG_02_15',
#                  'LEG_02_29',
#                  'LEG_02_24',
#                  'LEG_03_3',
#                  'LEG_03_2',
#                  'LEG_03_21',
#                  'LEG_03_4',
#                  'LEG_11_21',
#                  'LEG_11_4',
#                  'LEG_11_33',
#                  'LEG_12_7'],
#  'pairing 144': ['LEG_30_20', 'LEG_31_18'],
#  'pairing 145': ['LEG_03_5', 'LEG_04_7'],
#  'pairing 146': ['LEG_08_5', 'LEG_09_7'],
#  'pairing 147': ['LEG_22_1', 'LEG_22_32'],
#  'pairing 148': ['LEG_01_21', 'LEG_01_4'],
#  'pairing 149': ['LEG_18_25',
#                  'LEG_19_20',
#                  'LEG_19_19',
#                  'LEG_19_14',
#                  'LEG_20_2',
#                  'LEG_20_14',
#                  'LEG_20_24',
#                  'LEG_20_4',
#                  'LEG_20_27',
#                  'LEG_21_10',
#                  'LEG_22_19',
#                  'LEG_23_14',
#                  'LEG_23_13',
#                  'LEG_23_22'],
#  'pairing 15': ['LEG_19_2', 'LEG_19_1'],
#  'pairing 150': ['LEG_16_23',
#                  'LEG_16_18',
#                  'LEG_16_19',
#                  'LEG_17_14',
#                  'LEG_17_19',
#                  'LEG_18_14',
#                  'LEG_19_7',
#                  'LEG_19_17',
#                  'LEG_19_21',
#                  'LEG_20_22'],
#  'pairing 151': ['LEG_09_6', 'LEG_09_8'],
#  'pairing 152': ['LEG_02_9', 'LEG_03_32'],
#  'pairing 153': ['LEG_05_18', 'LEG_05_3'],
#  'pairing 154': ['LEG_23_27', 'LEG_23_28'],
#  'pairing 155': ['LEG_16_1', 'LEG_16_32'],
#  'pairing 156': ['LEG_11_25', 'LEG_11_27'],
#  'pairing 157': ['LEG_11_14', 'LEG_12_30'],
#  'pairing 158': ['LEG_08_29', 'LEG_08_24'],
#  'pairing 159': ['LEG_04_30', 'LEG_04_28'],
#  'pairing 16': ['LEG_27_25', 'LEG_27_24'],
#  'pairing 160': ['LEG_24_3', 'LEG_24_2'],
#  'pairing 161': ['LEG_01_18',
#                  'LEG_01_15',
#                  'LEG_01_32',
#                  'LEG_02_10',
#                  'LEG_02_11',
#                  'LEG_02_19'],
#  'pairing 162': ['LEG_19_26', 'LEG_19_25'],
#  'pairing 163': ['LEG_18_23',
#                  'LEG_18_18',
#                  'LEG_20_7',
#                  'LEG_20_19',
#                  'LEG_20_23',
#                  'LEG_21_23'],
#  'pairing 164': ['LEG_15_27', 'LEG_15_28'],
#  'pairing 165': ['LEG_11_6', 'LEG_11_8'],
#  'pairing 166': ['LEG_23_7', 'LEG_23_9'],
#  'pairing 167': ['LEG_23_5', 'LEG_24_8'],
#  'pairing 168': ['LEG_04_23',
#                  'LEG_05_19',
#                  'LEG_05_23',
#                  'LEG_05_13',
#                  'LEG_06_1',
#                  'LEG_06_12',
#                  'LEG_06_23',
#                  'LEG_06_13',
#                  'LEG_07_0',
#                  'LEG_07_1',
#                  'LEG_14_27',
#                  'LEG_14_17',
#                  'LEG_15_12',
#                  'LEG_15_21'],
#  'pairing 169': ['LEG_19_24', 'LEG_19_10'],
#  'pairing 17': ['LEG_26_26', 'LEG_26_3'],
#  'pairing 170': ['LEG_08_33',
#                  'LEG_09_10',
#                  'LEG_09_11',
#                  'LEG_09_19',
#                  'LEG_09_23',
#                  'LEG_10_22'],
#  'pairing 171': ['LEG_21_22',
#                  'LEG_21_17',
#                  'LEG_21_18',
#                  'LEG_22_14',
#                  'LEG_22_13',
#                  'LEG_22_22',
#                  'LEG_23_20',
#                  'LEG_23_15'],
#  'pairing 172': ['LEG_10_30', 'LEG_10_28'],
#  'pairing 173': ['LEG_30_28', 'LEG_31_26'],
#  'pairing 174': ['LEG_02_1', 'LEG_02_34'],
#  'pairing 175': ['LEG_09_5', 'LEG_10_7'],
#  'pairing 176': ['LEG_11_12',
#                  'LEG_11_20',
#                  'LEG_12_15',
#                  'LEG_12_11',
#                  'LEG_12_21',
#                  'LEG_12_12'],
#  'pairing 177': ['LEG_02_14', 'LEG_03_35'],
#  'pairing 178': ['LEG_15_3', 'LEG_15_2'],
#  'pairing 179': ['LEG_02_21', 'LEG_02_4'],
#  'pairing 18': ['LEG_01_0',
#                 'LEG_01_1',
#                 'LEG_01_31',
#                 'LEG_01_2',
#                 'LEG_01_29',
#                 'LEG_01_25',
#                 'LEG_02_25',
#                 'LEG_02_27',
#                 'LEG_06_3',
#                 'LEG_06_31',
#                 'LEG_09_1',
#                 'LEG_09_34',
#                 'LEG_10_26',
#                 'LEG_10_16'],
#  'pairing 180': ['LEG_08_6', 'LEG_08_8'],
#  'pairing 181': ['LEG_31_23', 'LEG_31_4'],
#  'pairing 182': ['LEG_06_30',
#                  'LEG_07_10',
#                  'LEG_07_12',
#                  'LEG_07_20',
#                  'LEG_08_18',
#                  'LEG_08_15'],
#  'pairing 183': ['LEG_04_25', 'LEG_04_27'],
#  'pairing 184': ['LEG_27_10',
#                  'LEG_27_17',
#                  'LEG_27_21',
#                  'LEG_28_20',
#                  'LEG_28_14',
#                  'LEG_28_10',
#                  'LEG_29_27',
#                  'LEG_29_14',
#                  'LEG_29_1',
#                  'LEG_30_11'],
#  'pairing 185': ['LEG_23_12',
#                  'LEG_23_21',
#                  'LEG_24_20',
#                  'LEG_24_15',
#                  'LEG_24_16',
#                  'LEG_24_6',
#                  'LEG_25_17',
#                  'LEG_25_26',
#                  'LEG_25_30',
#                  'LEG_25_0',
#                  'LEG_27_3',
#                  'LEG_28_12'],
#  'pairing 186': ['LEG_07_9', 'LEG_08_32'],
#  'pairing 187': ['LEG_17_17', 'LEG_17_26'],
#  'pairing 188': ['LEG_08_11',
#                  'LEG_08_19',
#                  'LEG_09_18',
#                  'LEG_09_15',
#                  'LEG_09_29',
#                  'LEG_09_24',
#                  'LEG_10_3',
#                  'LEG_10_2',
#                  'LEG_10_31',
#                  'LEG_10_0',
#                  'LEG_12_22',
#                  'LEG_12_24',
#                  'LEG_12_23',
#                  'LEG_12_13'],
#  'pairing 189': ['LEG_24_1', 'LEG_24_32'],
#  'pairing 19': ['LEG_13_30',
#                 'LEG_14_11',
#                 'LEG_14_18',
#                 'LEG_15_14',
#                 'LEG_16_12',
#                 'LEG_16_21',
#                 'LEG_16_25',
#                 'LEG_17_24'],
#  'pairing 190': ['LEG_16_27', 'LEG_16_28'],
#  'pairing 191': ['LEG_06_8',
#                  'LEG_06_16',
#                  'LEG_06_20',
#                  'LEG_07_22',
#                  'LEG_07_26',
#                  'LEG_07_16'],
#  'pairing 192': ['LEG_06_6', 'LEG_07_32'],
#  'pairing 193': ['LEG_12_26', 'LEG_12_25'],
#  'pairing 194': ['LEG_11_17', 'LEG_12_10'],
#  'pairing 195': ['LEG_27_18', 'LEG_27_19'],
#  'pairing 196': ['LEG_18_27', 'LEG_18_28'],
#  'pairing 197': ['LEG_04_14', 'LEG_05_30'],
#  'pairing 198': ['LEG_15_19', 'LEG_16_14'],
#  'pairing 199': ['LEG_03_1', 'LEG_03_34'],
#  'pairing 2': ['LEG_22_31',
#                'LEG_23_11',
#                'LEG_23_19',
#                'LEG_24_14',
#                'LEG_24_13',
#                'LEG_24_22',
#                'LEG_25_20',
#                'LEG_25_15'],
#  'pairing 20': ['LEG_26_9',
#                 'LEG_26_18',
#                 'LEG_27_22',
#                 'LEG_27_9',
#                 'LEG_27_11',
#                 'LEG_28_9',
#                 'LEG_28_1',
#                 'LEG_29_11'],
#  'pairing 200': ['LEG_09_9', 'LEG_10_32'],
#  'pairing 201': ['LEG_10_6', 'LEG_10_8'],
#  'pairing 202': ['LEG_25_31', 'LEG_26_7', 'LEG_27_0', 'LEG_27_12'],
#  'pairing 203': ['LEG_13_27', 'LEG_13_25'],
#  'pairing 204': ['LEG_03_25', 'LEG_03_27'],
#  'pairing 205': ['LEG_05_27', 'LEG_05_0'],
#  'pairing 206': ['LEG_14_26', 'LEG_14_28'],
#  'pairing 207': ['LEG_23_25',
#                  'LEG_24_24',
#                  'LEG_24_29',
#                  'LEG_24_4',
#                  'LEG_24_5',
#                  'LEG_25_8',
#                  'LEG_25_7',
#                  'LEG_25_9',
#                  'LEG_25_16',
#                  'LEG_25_6',
#                  'LEG_26_2',
#                  'LEG_26_1',
#                  'LEG_27_7',
#                  'LEG_28_21'],
#  'pairing 208': ['LEG_26_28', 'LEG_27_14', 'LEG_28_0', 'LEG_28_24'],
#  'pairing 209': ['LEG_01_3', 'LEG_01_33'],
#  'pairing 21': ['LEG_03_14', 'LEG_04_35'],
#  'pairing 210': ['LEG_13_18', 'LEG_13_4'],
#  'pairing 211': ['LEG_05_9',
#                  'LEG_05_17',
#                  'LEG_06_15',
#                  'LEG_06_11',
#                  'LEG_06_26',
#                  'LEG_06_21',
#                  'LEG_07_30',
#                  'LEG_07_28',
#                  'LEG_07_33',
#                  'LEG_08_10'],
#  'pairing 212': ['LEG_09_30', 'LEG_09_28'],
#  'pairing 213': ['LEG_18_3', 'LEG_18_2'],
#  'pairing 214': ['LEG_17_13',
#                  'LEG_17_22',
#                  'LEG_18_20',
#                  'LEG_18_15',
#                  'LEG_18_16',
#                  'LEG_18_6',
#                  'LEG_19_12',
#                  'LEG_19_23',
#                  'LEG_19_3',
#                  'LEG_19_5',
#                  'LEG_20_21',
#                  'LEG_20_15'],
#  'pairing 215': ['LEG_01_14', 'LEG_02_35'],
#  'pairing 216': ['LEG_15_5', 'LEG_16_8'],
#  'pairing 217': ['LEG_04_1', 'LEG_04_34'],
#  'pairing 218': ['LEG_17_1', 'LEG_17_32'],
#  'pairing 219': ['LEG_15_10', 'LEG_16_33'],
#  'pairing 22': ['LEG_02_33',
#                 'LEG_03_10',
#                 'LEG_03_11',
#                 'LEG_03_19',
#                 'LEG_03_23',
#                 'LEG_04_22'],
#  'pairing 220': ['LEG_14_0',
#                  'LEG_14_1',
#                  'LEG_14_32',
#                  'LEG_14_4',
#                  'LEG_14_5',
#                  'LEG_14_35',
#                  'LEG_14_7',
#                  'LEG_15_8',
#                  'LEG_15_7',
#                  'LEG_15_9',
#                  'LEG_15_31',
#                  'LEG_16_11'],
#  'pairing 221': ['LEG_07_3', 'LEG_07_34'],
#  'pairing 222': ['LEG_29_15', 'LEG_29_17'],
#  'pairing 223': ['LEG_09_21', 'LEG_09_4'],
#  'pairing 224': ['LEG_09_12',
#                  'LEG_09_20',
#                  'LEG_10_18',
#                  'LEG_10_15',
#                  'LEG_10_29',
#                  'LEG_10_24',
#                  'LEG_11_3',
#                  'LEG_11_2',
#                  'LEG_14_15',
#                  'LEG_15_33',
#                  'LEG_16_31',
#                  'LEG_17_11'],
#  'pairing 225': ['LEG_11_5', 'LEG_12_5'],
#  'pairing 226': ['LEG_21_0',
#                  'LEG_21_1',
#                  'LEG_21_29',
#                  'LEG_21_2',
#                  'LEG_21_3',
#                  'LEG_21_32',
#                  'LEG_21_5',
#                  'LEG_22_8',
#                  'LEG_22_30',
#                  'LEG_22_0',
#                  'LEG_24_17',
#                  'LEG_24_26',
#                  'LEG_24_23',
#                  'LEG_24_18'],
#  'pairing 227': ['LEG_04_21', 'LEG_04_4'],
#  'pairing 228': ['LEG_21_12',
#                  'LEG_21_21',
#                  'LEG_22_20',
#                  'LEG_22_15',
#                  'LEG_22_16',
#                  'LEG_22_6',
#                  'LEG_23_17',
#                  'LEG_23_26',
#                  'LEG_23_29',
#                  'LEG_23_4',
#                  'LEG_26_22',
#                  'LEG_26_13'],
#  'pairing 229': ['LEG_25_10', 'LEG_26_29'],
#  'pairing 23': ['LEG_18_1', 'LEG_18_32'],
#  'pairing 230': ['LEG_31_25', 'LEG_31_6'],
#  'pairing 231': ['LEG_15_29', 'LEG_15_4'],
#  'pairing 232': ['LEG_27_6', 'LEG_28_12', 'LEG_29_0', 'LEG_29_22'],
#  'pairing 233': ['LEG_31_2', 'LEG_31_29'],
#  'pairing 234': ['LEG_29_23', 'LEG_29_4'],
#  'pairing 235': ['LEG_05_29',
#                  'LEG_06_7',
#                  'LEG_07_11',
#                  'LEG_07_19',
#                  'LEG_07_23',
#                  'LEG_08_22'],
#  'pairing 236': ['LEG_19_27', 'LEG_19_0'],
#  'pairing 237': ['LEG_13_3', 'LEG_13_31'],
#  'pairing 238': ['LEG_29_2', 'LEG_29_29'],
#  'pairing 239': ['LEG_03_9', 'LEG_04_32'],
#  'pairing 24': ['LEG_25_25',
#                 'LEG_26_20',
#                 'LEG_26_19',
#                 'LEG_26_14',
#                 'LEG_26_15',
#                 'LEG_27_5',
#                 'LEG_27_4',
#                 'LEG_27_26',
#                 'LEG_27_8',
#                 'LEG_27_15',
#                 'LEG_30_7',
#                 'LEG_30_13'],
#  'pairing 240': ['LEG_11_9', 'LEG_12_28'],
#  'pairing 241': ['LEG_01_30', 'LEG_01_28'],
#  'pairing 242': ['LEG_08_9', 'LEG_09_32'],
#  'pairing 243': ['LEG_06_22', 'LEG_06_24'],
#  'pairing 244': ['LEG_22_5', 'LEG_23_8'],
#  'pairing 245': ['LEG_10_23',
#                  'LEG_11_22',
#                  'LEG_11_26',
#                  'LEG_11_16',
#                  'LEG_12_8',
#                  'LEG_12_16'],
#  'pairing 246': ['LEG_30_8', 'LEG_31_9'],
#  'pairing 247': ['LEG_16_30', 'LEG_16_0'],
#  'pairing 248': ['LEG_09_3', 'LEG_09_2'],
#  'pairing 25': ['LEG_20_8',
#                 'LEG_20_20',
#                 'LEG_21_19',
#                 'LEG_21_14',
#                 'LEG_21_15',
#                 'LEG_21_6',
#                 'LEG_22_17',
#                 'LEG_22_26',
#                 'LEG_22_7',
#                 'LEG_22_9',
#                 'LEG_22_10',
#                 'LEG_23_33',
#                 'LEG_23_23',
#                 'LEG_23_18'],
#  'pairing 26': ['LEG_05_2', 'LEG_05_1'],
#  'pairing 27': ['LEG_14_13',
#                 'LEG_14_21',
#                 'LEG_15_20',
#                 'LEG_15_15',
#                 'LEG_15_16',
#                 'LEG_15_6',
#                 'LEG_16_17',
#                 'LEG_16_26',
#                 'LEG_16_7',
#                 'LEG_16_9',
#                 'LEG_16_10',
#                 'LEG_17_33',
#                 'LEG_17_23',
#                 'LEG_17_18'],
#  'pairing 28': ['LEG_03_31', 'LEG_03_0'],
#  'pairing 29': ['LEG_02_12',
#                 'LEG_02_20',
#                 'LEG_03_18',
#                 'LEG_03_15',
#                 'LEG_03_29',
#                 'LEG_03_24',
#                 'LEG_04_3',
#                 'LEG_04_2',
#                 'LEG_04_31',
#                 'LEG_04_0',
#                 'LEG_04_9',
#                 'LEG_05_28',
#                 'LEG_05_21',
#                 'LEG_05_12'],
#  'pairing 3': ['LEG_18_29', 'LEG_18_4'],
#  'pairing 30': ['LEG_16_3', 'LEG_16_2'],
#  'pairing 31': ['LEG_16_13',
#                 'LEG_16_22',
#                 'LEG_17_20',
#                 'LEG_17_15',
#                 'LEG_17_16',
#                 'LEG_17_6',
#                 'LEG_18_17',
#                 'LEG_18_26',
#                 'LEG_18_7',
#                 'LEG_18_9',
#                 'LEG_18_5',
#                 'LEG_19_4',
#                 'LEG_19_28',
#                 'LEG_20_6'],
#  'pairing 32': ['LEG_28_22', 'LEG_29_18'],
#  'pairing 33': ['LEG_15_13',
#                 'LEG_15_22',
#                 'LEG_16_20',
#                 'LEG_16_15',
#                 'LEG_16_16',
#                 'LEG_16_6',
#                 'LEG_17_3',
#                 'LEG_17_2',
#                 'LEG_23_16',
#                 'LEG_23_6',
#                 'LEG_24_10',
#                 'LEG_25_33',
#                 'LEG_25_23',
#                 'LEG_25_18'],
#  'pairing 34': ['LEG_03_12',
#                 'LEG_03_20',
#                 'LEG_04_18',
#                 'LEG_04_15',
#                 'LEG_04_29',
#                 'LEG_04_24',
#                 'LEG_05_26',
#                 'LEG_05_25',
#                 'LEG_10_1',
#                 'LEG_10_34',
#                 'LEG_13_22',
#                 'LEG_13_24',
#                 'LEG_13_23',
#                 'LEG_13_13'],
#  'pairing 35': ['LEG_09_25', 'LEG_09_27'],
#  'pairing 36': ['LEG_26_27', 'LEG_26_0'],
#  'pairing 37': ['LEG_05_22', 'LEG_05_24'],
#  'pairing 38': ['LEG_24_19', 'LEG_25_14'],
#  'pairing 39': ['LEG_09_33',
#                 'LEG_10_10',
#                 'LEG_10_17',
#                 'LEG_11_13',
#                 'LEG_13_8',
#                 'LEG_13_16',
#                 'LEG_13_20',
#                 'LEG_14_23'],
#  'pairing 4': ['LEG_21_7', 'LEG_21_8'],
#  'pairing 40': ['LEG_21_31',
#                 'LEG_22_11',
#                 'LEG_22_12',
#                 'LEG_22_21',
#                 'LEG_22_25',
#                 'LEG_23_24'],
#  'pairing 41': ['LEG_13_5', 'LEG_14_9'],
#  'pairing 42': ['LEG_24_7', 'LEG_24_9'],
#  'pairing 43': ['LEG_08_25', 'LEG_08_27'],
#  'pairing 44': ['LEG_25_12',
#                 'LEG_25_21',
#                 'LEG_26_21',
#                 'LEG_27_20',
#                 'LEG_27_16',
#                 'LEG_27_13',
#                 'LEG_28_28',
#                 'LEG_28_16',
#                 'LEG_28_17',
#                 'LEG_28_19',
#                 'LEG_28_18',
#                 'LEG_28_26'],
#  'pairing 45': ['LEG_25_19', 'LEG_26_10'],
#  'pairing 46': ['LEG_10_21', 'LEG_10_4'],
#  'pairing 47': ['LEG_10_9', 'LEG_11_32'],
#  'pairing 48': ['LEG_02_6', 'LEG_02_8'],
#  'pairing 49': ['LEG_01_9', 'LEG_02_32'],
#  'pairing 5': ['LEG_22_27', 'LEG_22_28'],
#  'pairing 50': ['LEG_07_14', 'LEG_08_35'],
#  'pairing 51': ['LEG_06_18', 'LEG_06_4'],
#  'pairing 52': ['LEG_29_3', 'LEG_30_19', 'LEG_30_21', 'LEG_30_29'],
#  'pairing 53': ['LEG_09_14', 'LEG_10_35'],
#  'pairing 54': ['LEG_01_11',
#                 'LEG_01_19',
#                 'LEG_01_23',
#                 'LEG_02_22',
#                 'LEG_02_26',
#                 'LEG_02_16'],
#  'pairing 55': ['LEG_10_14', 'LEG_11_35'],
#  'pairing 56': ['LEG_02_3', 'LEG_02_2'],
#  'pairing 57': ['LEG_25_27', 'LEG_25_28'],
#  'pairing 58': ['LEG_10_25', 'LEG_10_27'],
#  'pairing 59': ['LEG_30_23', 'LEG_30_4'],
#  'pairing 6': ['LEG_28_13',
#                'LEG_28_25',
#                'LEG_28_4',
#                'LEG_28_3',
#                'LEG_29_19',
#                'LEG_29_12',
#                'LEG_29_10',
#                'LEG_30_27',
#                'LEG_30_14',
#                'LEG_30_2',
#                'LEG_30_5',
#                'LEG_31_16',
#                'LEG_31_24'],
#  'pairing 60': ['LEG_21_9', 'LEG_22_33'],
#  'pairing 61': ['LEG_17_5', 'LEG_18_8'],
#  'pairing 62': ['LEG_18_10', 'LEG_19_29'],
#  'pairing 63': ['LEG_18_31',
#                 'LEG_19_6',
#                 'LEG_19_15',
#                 'LEG_20_9',
#                 'LEG_20_16',
#                 'LEG_21_13',
#                 'LEG_24_12',
#                 'LEG_24_21',
#                 'LEG_31_12',
#                 'LEG_31_10'],
#  'pairing 64': ['LEG_10_12',
#                 'LEG_10_20',
#                 'LEG_11_18',
#                 'LEG_11_15',
#                 'LEG_11_29',
#                 'LEG_11_24',
#                 'LEG_12_4',
#                 'LEG_12_6',
#                 'LEG_20_13',
#                 'LEG_20_0'],
#  'pairing 65': ['LEG_12_20',
#                 'LEG_13_19',
#                 'LEG_13_29',
#                 'LEG_13_0',
#                 'LEG_18_19',
#                 'LEG_19_9',
#                 'LEG_19_8',
#                 'LEG_19_18'],
#  'pairing 66': ['LEG_23_31',
#                 'LEG_24_11',
#                 'LEG_26_8',
#                 'LEG_26_17',
#                 'LEG_28_23',
#                 'LEG_28_5'],
#  'pairing 67': ['LEG_14_8', 'LEG_14_10'],
#  'pairing 68': ['LEG_28_8', 'LEG_29_9'],
#  'pairing 69': ['LEG_31_27', 'LEG_31_14'],
#  'pairing 7': ['LEG_12_9',
#                'LEG_12_17',
#                'LEG_13_15',
#                'LEG_13_11',
#                'LEG_13_26',
#                'LEG_13_21',
#                'LEG_14_31',
#                'LEG_14_29',
#                'LEG_14_30',
#                'LEG_14_25',
#                'LEG_15_17',
#                'LEG_15_26',
#                'LEG_15_23',
#                'LEG_15_18'],
#  'pairing 70': ['LEG_12_2', 'LEG_12_1'],
#  'pairing 71': ['LEG_20_18',
#                 'LEG_20_10',
#                 'LEG_20_11',
#                 'LEG_20_5',
#                 'LEG_21_16',
#                 'LEG_21_25',
#                 'LEG_21_26',
#                 'LEG_21_27',
#                 'LEG_21_28',
#                 'LEG_21_4',
#                 'LEG_29_28',
#                 'LEG_30_26',
#                 'LEG_30_3',
#                 'LEG_31_19'],
#  'pairing 72': ['LEG_10_5', 'LEG_11_7'],
#  'pairing 73': ['LEG_06_27', 'LEG_06_25'],
#  'pairing 74': ['LEG_11_31', 'LEG_11_0'],
#  'pairing 75': ['LEG_06_29', 'LEG_06_0', 'LEG_31_0', 'LEG_31_22'],
#  'pairing 76': ['LEG_13_9',
#                 'LEG_13_17',
#                 'LEG_14_19',
#                 'LEG_14_16',
#                 'LEG_14_3',
#                 'LEG_14_2'],
#  'pairing 77': ['LEG_15_25',
#                 'LEG_16_24',
#                 'LEG_16_29',
#                 'LEG_16_4',
#                 'LEG_16_5',
#                 'LEG_17_8',
#                 'LEG_17_7',
#                 'LEG_17_9',
#                 'LEG_17_31',
#                 'LEG_18_11',
#                 'LEG_18_12',
#                 'LEG_18_21'],
#  'pairing 78': ['LEG_13_6', 'LEG_14_33'],
#  'pairing 79': ['LEG_18_13',
#                 'LEG_18_22',
#                 'LEG_19_16',
#                 'LEG_19_11',
#                 'LEG_19_22',
#                 'LEG_19_13'],
#  'pairing 8': ['LEG_09_31', 'LEG_09_0'],
#  'pairing 80': ['LEG_07_25', 'LEG_07_27'],
#  'pairing 81': ['LEG_25_3', 'LEG_25_2'],
#  'pairing 82': ['LEG_24_25',
#                 'LEG_25_24',
#                 'LEG_25_29',
#                 'LEG_25_4',
#                 'LEG_25_5',
#                 'LEG_26_5',
#                 'LEG_26_4',
#                 'LEG_26_6',
#                 'LEG_27_1',
#                 'LEG_27_2',
#                 'LEG_27_23',
#                 'LEG_28_11',
#                 'LEG_28_7',
#                 'LEG_28_15'],
#  'pairing 83': ['LEG_17_29', 'LEG_17_4'],
#  'pairing 84': ['LEG_03_6', 'LEG_03_8'],
#  'pairing 85': ['LEG_24_27', 'LEG_24_28'],
#  'pairing 86': ['LEG_01_5', 'LEG_02_7'],
#  'pairing 87': ['LEG_17_30', 'LEG_17_0'],
#  'pairing 88': ['LEG_24_30', 'LEG_24_0'],
#  'pairing 89': ['LEG_28_29', 'LEG_29_26'],
#  'pairing 9': ['LEG_07_21', 'LEG_07_4'],
#  'pairing 90': ['LEG_12_14', 'LEG_13_10'],
#  'pairing 91': ['LEG_17_10', 'LEG_18_33'],
#  'pairing 92': ['LEG_30_15', 'LEG_30_17'],
#  'pairing 93': ['LEG_04_5', 'LEG_05_5'],
#  'pairing 94': ['LEG_25_1', 'LEG_25_32'],
#  'pairing 95': ['LEG_17_27', 'LEG_17_28'],
#  'pairing 96': ['LEG_20_26', 'LEG_20_25'],
#  'pairing 97': ['LEG_29_21',
#                 'LEG_29_5',
#                 'LEG_29_16',
#                 'LEG_29_24',
#                 'LEG_30_0',
#                 'LEG_30_22',
#                 'LEG_30_1',
#                 'LEG_31_11',
#                 'LEG_31_7',
#                 'LEG_31_13'],
#  'pairing 98': ['LEG_03_30', 'LEG_03_28'],
#  'pairing 99': ['LEG_02_30', 'LEG_02_28']}

# %%
print('Key Performance Indicators:')
pprint(kpi)
# Out:
# Key Performance Indicators:
# {'avg flying hr time': 7.59,
#  'flying hours standard deviation ': 7.51,
#  'max flying hr time': 28.58,
#  'max rest time': 872.0,
#  'min flying hr time': 1.3,
#  'min rest time': 18.0,
#  'number of deadhead flights': 1,
#  'number of flight legs not covered': 0,
#  'pairings': 248}

# %% [markdown]
# ### 4. Clean-up

# %% [markdown]
# #### Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the algorithm, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
